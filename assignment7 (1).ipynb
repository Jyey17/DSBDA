# %%
import nltk
import math
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
documentA = 'Jupiter is the largest Planet'
documentB = 'Mars is the fourth planet from the Sun'

# %%
documents = [documentA, documentB]

# %%
stop_words = set(stopwords.words('english'))

# %%
processed_docs = []

# %%
for doc in documents:
    doc = doc.lower()
    words = word_tokenize(doc)
    filtered_words = [w for w in words if w not in stop_words]
    processed_docs.append(filtered_words)

# %%
print("Processed Documents:", processed_docs)
# Out:
# Processed Documents: [['jupiter', 'largest', 'planet'], ['mars', 'fourth', 'planet', 'sun']]

# %%
vocab = set()
for doc in processed_docs:
    vocab.update(doc)

# %%
vocab = list(vocab)

# %%
def compute_tf(doc):
    tf_dict = {}
    doc_len = len(doc)
    for word in vocab:
        tf_dict[word] = doc.count(word) / doc_len
    return tf_dict

# %%
tf_docs = [compute_tf(doc) for doc in processed_docs]

# %%
def compute_idf(docs):
    N = len(docs)
    idf_dict = {}
    for word in vocab:
        count = sum(1 for doc in docs if word in doc)
        idf_dict[word] = math.log(N / (count + 1)) + 1 
        return idf_dict

# %%
idf = compute_idf(processed_docs)

# %%
def compute_tfidf(tf, idf):
    tfidf = {}
    for word in vocab:
        tfidf[word] = tf.get(word, 0) * idf.get(word, 0)
    return tfidf

tfidf_docs = [compute_tfidf(tf, idf) for tf in tf_docs]

# %%
# Output
print("\nVocabulary:", vocab)

print("\nTF for each document:")
for i, tf in enumerate(tf_docs):
    print(f"Document {i+1}:", tf)

print("\nIDF values:")
print(idf)
print("\nTF-IDF for each document:")
for i, tfidf in enumerate(tfidf_docs):
    print(f"Document {i+1}:", tfidf)
# Out:
# Vocabulary: ['sun', 'planet', 'jupiter', 'fourth', 'mars', 'largest']
#
# TF for each document:
# Document 1: {'sun': 0.0, 'planet': 0.3333333333333333, 'jupiter': 0.3333333333333333, 'fourth': 0.0, 'mars': 0.0, 'largest': 0.3333333333333333}
# Document 2: {'sun': 0.25, 'planet': 0.25, 'jupiter': 0.0, 'fourth': 0.25, 'mars': 0.25, 'largest': 0.0}
#
# IDF values:
# {'sun': 1.0}
#
# TF-IDF for each document:
# Document 1: {'sun': 0.0, 'planet': 0.0, 'jupiter': 0.0, 'fourth': 0.0, 'mars': 0.0, 'largest': 0.0}
# Document 2: {'sun': 0.25, 'planet': 0.0, 'jupiter': 0.0, 'fourth': 0.0, 'mars': 0.0, 'largest': 0.0}
