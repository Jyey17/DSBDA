# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("Book2.csv")

# %%
df
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0        72.0            NaN           74.0    2023.0               92
# 1        64.0            NaN           60.0    2020.0               82
# 2        80.0            NaN           80.0       NaN               86
# 3        73.0            NaN           64.0       NaN               92
# 4        63.0           93.0           66.0       NaN               90
# ..        ...            ...            ...       ...              ...
# 95       60.0           80.0           60.0    2020.0               87
# 96       66.0            NaN           63.0    2020.0               94
# 97       78.0            NaN           74.0    2020.0               84
# 98       64.0            NaN           79.0    2020.0               81
# 99       70.0           89.0           72.0    2020.0               99
#
#     placement offer
# 0                 2
# 1                 3
# 2                 2
# 3                 2
# ...

# %%
ndf=df

# %%
ndf.fillna(0)
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0        72.0            0.0           74.0    2023.0               92
# 1        64.0            0.0           60.0    2020.0               82
# 2        80.0            0.0           80.0       0.0               86
# 3        73.0            0.0           64.0       0.0               92
# 4        63.0           93.0           66.0       0.0               90
# ..        ...            ...            ...       ...              ...
# 95       60.0           80.0           60.0    2020.0               87
# 96       66.0            0.0           63.0    2020.0               94
# 97       78.0            0.0           74.0    2020.0               84
# 98       64.0            0.0           79.0    2020.0               81
# 99       70.0           89.0           72.0    2020.0               99
#
#     placement offer
# 0                 2
# 1                 3
# 2                 2
# 3                 2
# ...

# %%
m_v=df['mathscore'].mean()

# %%
df['mathscore'].fillna(value=m_v, inplace=True)

# %%
df
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0        72.0            NaN           74.0    2023.0               92
# 1        64.0            NaN           60.0    2020.0               82
# 2        80.0            NaN           80.0       NaN               86
# 3        73.0            NaN           64.0       NaN               92
# 4        63.0           93.0           66.0       NaN               90
# ..        ...            ...            ...       ...              ...
# 95       60.0           80.0           60.0    2020.0               87
# 96       66.0            NaN           63.0    2020.0               94
# 97       78.0            NaN           74.0    2020.0               84
# 98       64.0            NaN           79.0    2020.0               81
# 99       70.0           89.0           72.0    2020.0               99
#
#     placement offer
# 0                 2
# 1                 3
# 2                 2
# 3                 2
# ...

# %%
ndf.replace(to_replace = np.nan, value = -99)
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0        72.0          -99.0           74.0    2023.0               92
# 1        64.0          -99.0           60.0    2020.0               82
# 2        80.0          -99.0           80.0     -99.0               86
# 3        73.0          -99.0           64.0     -99.0               92
# 4        63.0           93.0           66.0     -99.0               90
# ..        ...            ...            ...       ...              ...
# 95       60.0           80.0           60.0    2020.0               87
# 96       66.0          -99.0           63.0    2020.0               94
# 97       78.0          -99.0           74.0    2020.0               84
# 98       64.0          -99.0           79.0    2020.0               81
# 99       70.0           89.0           72.0    2020.0               99
#
#     placement offer
# 0                 2
# 1                 3
# 2                 2
# 3                 2
# ...

# %%
df=pd.read_csv("Book2.csv")

# %%
df
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0        72.0            NaN           74.0    2023.0               92
# 1        64.0            NaN           60.0    2020.0               82
# 2        80.0            NaN           80.0       NaN               86
# 3        73.0            NaN           64.0       NaN               92
# 4        63.0           93.0           66.0       NaN               90
# ..        ...            ...            ...       ...              ...
# 95       60.0           80.0           60.0    2020.0               87
# 96       66.0            NaN           63.0    2020.0               94
# 97       78.0            NaN           74.0    2020.0               84
# 98       64.0            NaN           79.0    2020.0               81
# 99       70.0           89.0           72.0    2020.0               99
#
#     placement offer
# 0                 2
# 1                 3
# 2                 2
# 3                 2
# ...

# %%
ndf.dropna()
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 13  69.819149           76.0           70.0    2023.0               92
# 14  69.819149           93.0           77.0    2022.0               81
# 15  69.819149           80.0           77.0    2022.0               97
# 16  69.819149           79.0           68.0    2022.0               81
# 17  78.000000           80.0           80.0    2020.0               96
# ..        ...            ...            ...       ...              ...
# 92  70.000000           81.0           62.0    2020.0               80
# 93  65.000000           79.0           78.0    2020.0               95
# 94  80.000000           84.0           78.0    2020.0               76
# 95  60.000000           80.0           60.0    2020.0               87
# 99  70.000000           89.0           72.0    2020.0               99
#
#     placement offer
# 13                2
# 14                3
# 15                2
# 16                3
# ...

# %%
ndf.dropna(how = 'all')
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0        72.0            NaN           74.0    2023.0               92
# 1        64.0            NaN           60.0    2020.0               82
# 2        80.0            NaN           80.0       NaN               86
# 3        73.0            NaN           64.0       NaN               92
# 4        63.0           93.0           66.0       NaN               90
# ..        ...            ...            ...       ...              ...
# 95       60.0           80.0           60.0    2020.0               87
# 96       66.0            NaN           63.0    2020.0               94
# 97       78.0            NaN           74.0    2020.0               84
# 98       64.0            NaN           79.0    2020.0               81
# 99       70.0           89.0           72.0    2020.0               99
#
#     placement offer
# 0                 2
# 1                 3
# 2                 2
# 3                 2
# ...

# %%
ndf.dropna(axis = 1)
# Out:
#     mathscore  placement score  placement offer
# 0        72.0               92                2
# 1        64.0               82                3
# 2        80.0               86                2
# 3        73.0               92                2
# 4        63.0               90                2
# ..        ...              ...              ...
# 95       60.0               87                2
# 96       66.0               94                2
# 97       78.0               84                3
# 98       64.0               81                3
# 99       70.0               99                2
#
# [100 rows x 3 columns]

# %%
new_data = ndf.dropna(axis = 0, how ='any')

# %%
col = ['mathscore', 'reading score' , 'writing score','placement score']

# %%
col = ['mathscore', 'reading score' , 'writing score','placement score']

# %%
df.boxplot(col)
# Out:
# <Axes: >

# %%
print(np.where(df['mathscore']>90))
# Out:
# (array([], dtype=int64),)

# %%
print(np.where(df['reading score']<25))
# Out:
# (array([], dtype=int64),)

# %%
print(np.where(df['writing score']<30))
# Out:
# (array([], dtype=int64),)

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Book2.csv")

# %%
df
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0        72.0            NaN           74.0    2023.0               92
# 1        64.0            NaN           60.0    2020.0               82
# 2        80.0            NaN           80.0       NaN               86
# 3        73.0            NaN           64.0       NaN               92
# 4        63.0           93.0           66.0       NaN               90
# ..        ...            ...            ...       ...              ...
# 95       60.0           80.0           60.0    2020.0               87
# 96       66.0            NaN           63.0    2020.0               94
# 97       78.0            NaN           74.0    2020.0               84
# 98       64.0            NaN           79.0    2020.0               81
# 99       70.0           89.0           72.0    2020.0               99
#
#     placement offer
# 0                 2
# 1                 3
# 2                 2
# 3                 2
# ...

# %%
fig, ax = plt.subplots(figsize = (18,10))

# %%
ax.scatter(df['placement score'], df['placement offer'])

# %%
plt.show()

# %%
ax.set_xlabel('(Proportion non-retail business acres)/(town)')
# Out:
# Text(0.5, 4.4444444444444375, '(Proportion non-retail business acres)/(town)')

# %%
ax.set_ylabel('(Full-value property-tax rate)/($10,000)')
# Out:
# Text(4.444444444444452, 0.5, '(Full-value property-tax rate)/($10,000)')

# %%
print(np.where((df['placement score']<50) & (df['placement offer']>1)))
# Out:
# (array([], dtype=int64),)

# %%
print(np.where((df['placement score']>85) & (df['placement offer']<3)))
# Out:
# (array([ 0,  2,  3,  4,  5,  7,  8, 12, 13, 15, 17, 18, 19, 20, 22, 23, 24,
#        26, 27, 28, 30, 31, 32, 33, 37, 39, 42, 43, 44, 51, 52, 53, 55, 56,
#        57, 59, 61, 62, 63, 64, 65, 66, 68, 70, 71, 72, 75, 76, 78, 80, 82,
#        84, 88, 91, 93, 95, 96, 99]),)

# %%
import numpy as np

# %%
from scipy import stats

# %%
z = np.abs(stats.zscore(df['mathscore']))

# %%
df['mathscore']
# Out:
# 0     72.0
# 1     64.0
# 2     80.0
# 3     73.0
# 4     63.0
#       ...
# 95    60.0
# 96    66.0
# 97    78.0
# 98    64.0
# 99    70.0
# Name: mathscore, Length: 100, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   mathscore        94 non-null     float64
#  1   reading score    92 non-null     float64
#  2   writing score    91 non-null     float64
#  3   clubjoin         93 non-null     float64
#  4   placement score  100 non-null    int64
#  5   placement offer  100 non-null    int64
# dtypes: float64(4), int64(2)
# memory usage: 4.8 KB

# %%
df.mathscore.isnull().sum()
# Out:
# np.int64(6)

# %%
df.mathscore.isnull().sum()
# Out:
# np.int64(6)

# %%
df=pd.read_csv("Book2.csv")

# %%
df.mathscore.isnull().sum()
# Out:
# np.int64(0)

# %%
df['mathscore']
# Out:
# 0     72
# 1     64
# 2     80
# 3     73
# 4     63
#       ..
# 95    60
# 96    66
# 97    78
# 98    64
# 99    70
# Name: mathscore, Length: 100, dtype: int64

# %%
z = np.abs(stats.zscore(df['mathscore']))

# %%
z = np.abs(stats.zscore(df['mathscore']))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   mathscore        100 non-null    int64
#  1   reading score    92 non-null     float64
#  2   writing score    91 non-null     float64
#  3   clubjoin         93 non-null     float64
#  4   placement score  100 non-null    int64
#  5   placement offer  100 non-null    int64
# dtypes: float64(3), int64(3)
# memory usage: 4.8 KB

# %%
z = np.abs(stats.zscore(df['mathscore']))

# %%
print(z)
# Out:
# [0.29072513 0.95301875 1.53446901 0.44619312 1.10848673 1.53446901
#  1.26395471 0.13525715 0.79755076 1.4194227  0.75712908 0.75712908
#  0.75712908 0.75712908 0.75712908 0.75712908 0.75712908 1.22353304
#  1.26395471 0.33114681 0.29072513 1.10848673 0.17567882 1.06806505
#  0.95301875 1.57489068 1.37900102 0.13525715 1.06806505 0.33114681
#  0.79755076 0.95301875 0.13525715 0.02021084 0.95301875 0.33114681
#  1.22353304 1.53446901 1.53446901 0.29072513 1.10848673 1.37900102
#  0.75712908 1.10848673 1.57489068 0.29072513 1.10848673 1.57489068
#  1.26395471 0.29072513 1.37900102 0.33114681 1.4194227  0.48661479
#  0.75712908 0.29072513 0.79755076 0.95301875 0.13525715 0.17567882
#  0.13525715 1.53446901 1.10848673 0.48661479 0.95301875 0.33114681
#  1.57489068 0.29072513 1.22353304 0.91259707 0.48661479 1.53446901
#  0.91259707 0.75712908 0.79755076 1.53446901 0.91259707 0.33114681
#  1.26395471 1.53446901 0.91259707 0.75712908 1.57489068 0.48661479
# ...

# %%
threshold = 0.18

# %%
sample_outliers = np.where(z <threshold)

# %%
sample_outliers
# Out:
# (array([ 7, 22, 27, 32, 33, 58, 59, 60, 92, 99]),)

# %%
import numpy as np

# %%
sorted_rscore= sorted(df['reading score'])

# %%
sorted_rscore
# Out:
# [75.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  75.0,
#  75.0,
#  75.0,
#  75.0,
#  75.0,
#  75.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  77.0,
#  77.0,
#  77.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  79.0,
#  79.0,
#  79.0,
#  80.0,
#  80.0,
#  80.0,
#  80.0,
#  81.0,
#  81.0,
#  81.0,
#  82.0,
#  82.0,
#  82.0,
#  82.0,
#  82.0,
#  83.0,
#  83.0,
#  84.0,
#  84.0,
#  84.0,
#  84.0,
#  85.0,
#  85.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  88.0,
#  88.0,
#  88.0,
#  88.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  90.0,
#  90.0,
#  91.0,
#  91.0,
#  91.0,
#  91.0,
#  91.0,
#  92.0,
#  92.0,
#  93.0,
#  93.0,
#  93.0,
#  93.0,
#  93.0,
#  93.0,
#  93.0,
#  94.0,
#  94.0,
#  94.0,
#  95.0,
#  95.0,
#  95.0,
#  nan,
#  nan,
#  nan,
#  nan]

# %%
q1 = np.percentile(sorted_rscore, 25)

# %%
q3 = np.percentile(sorted_rscore, 75)

# %%
print(q1,q3)
# Out:
# nan nan

# %%
sorted_rscore
# Out:
# [75.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  75.0,
#  75.0,
#  75.0,
#  75.0,
#  75.0,
#  75.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  77.0,
#  77.0,
#  77.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  79.0,
#  79.0,
#  79.0,
#  80.0,
#  80.0,
#  80.0,
#  80.0,
#  81.0,
#  81.0,
#  81.0,
#  82.0,
#  82.0,
#  82.0,
#  82.0,
#  82.0,
#  83.0,
#  83.0,
#  84.0,
#  84.0,
#  84.0,
#  84.0,
#  85.0,
#  85.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  88.0,
#  88.0,
#  88.0,
#  88.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  90.0,
#  90.0,
#  91.0,
#  91.0,
#  91.0,
#  91.0,
#  91.0,
#  92.0,
#  92.0,
#  93.0,
#  93.0,
#  93.0,
#  93.0,
#  93.0,
#  93.0,
#  93.0,
#  94.0,
#  94.0,
#  94.0,
#  95.0,
#  95.0,
#  95.0,
#  nan,
#  nan,
#  nan,
#  nan]

# %%
df=pd.read_csv("Book2.csv")

# %%
df=pd.read_csv("Book2.csv")

# %%
df=pd.read_csv("Book2.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   mathscore        100 non-null    int64
#  1   reading score    100 non-null    int64
#  2   writing score    91 non-null     float64
#  3   clubjoin         93 non-null     float64
#  4   placement score  100 non-null    int64
#  5   placement offer  100 non-null    int64
# dtypes: float64(2), int64(4)
# memory usage: 4.8 KB

# %%
sorted_rscore= sorted(df['reading score'])

# %%
sorted_rscore
# Out:
# [75,
#  75,
#  75,
#  75,
#  75,
#  75,
#  75,
#  76,
#  76,
#  76,
#  76,
#  76,
#  76,
#  76,
#  76,
#  76,
#  76,
#  77,
#  77,
#  77,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  79,
#  79,
#  79,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  81,
#  81,
#  81,
#  82,
#  82,
#  82,
#  82,
#  82,
#  83,
#  83,
#  84,
#  84,
#  84,
#  84,
#  85,
#  85,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  87,
#  87,
#  87,
#  87,
#  88,
#  88,
#  88,
#  88,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  90,
#  90,
#  91,
#  91,
#  91,
#  91,
#  91,
#  92,
#  92,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  94,
#  94,
#  94,
#  95,
#  95,
#  95]

# %%
q1 = np.percentile(sorted_rscore, 25)

# %%
q3 = np.percentile(sorted_rscore, 75)

# %%
print(q1,q3)
# Out:
# 78.0 90.0

# %%
IQR = q3-q1

# %%
lwr_bound = q1-(1.5*IQR)

# %%
upr_bound = q3+(1.5*IQR)

# %%
print(lwr_bound, upr_bound)
# Out:
# 60.0 108.0

# %%
r_outliers = []

# %%
r_outliers = []

for i in sorted_rscore:
    if i < lwr_bound or i > upr_bound:
        r_outliers.append(i)

# %%
print(r_outliers)
# Out:
# []

# %%
df=pd.read_csv("Book2.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   mathscore        100 non-null    int64
#  1   reading score    100 non-null    int64
#  2   writing score    91 non-null     float64
#  3   clubjoin         93 non-null     float64
#  4   placement score  100 non-null    int64
#  5   placement offer  100 non-null    int64
# dtypes: float64(2), int64(4)
# memory usage: 4.8 KB

# %%
sorted_rscore= sorted(df['reading score'])

# %%
sorted_rscore
# Out:
# [25,
#  25,
#  25,
#  25,
#  30,
#  30,
#  30,
#  30,
#  30,
#  75,
#  75,
#  75,
#  75,
#  75,
#  75,
#  76,
#  76,
#  76,
#  76,
#  76,
#  76,
#  76,
#  76,
#  77,
#  77,
#  77,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  79,
#  79,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  81,
#  81,
#  81,
#  82,
#  82,
#  82,
#  82,
#  82,
#  83,
#  83,
#  84,
#  84,
#  84,
#  85,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  87,
#  87,
#  87,
#  87,
#  88,
#  88,
#  88,
#  88,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  90,
#  90,
#  91,
#  91,
#  91,
#  91,
#  91,
#  92,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  94,
#  94,
#  94,
#  95,
#  95,
#  95]

# %%
q1 = np.percentile(sorted_rscore, 25)

# %%
q3 = np.percentile(sorted_rscore, 75)

# %%
print(q1,q3)
# Out:
# 77.0 89.0

# %%
IQR = q3-q1

# %%
lwr_bound = q1-(1.5*IQR)

# %%
upr_bound = q3+(1.5*IQR)

# %%
print(lwr_bound, upr_bound)
# Out:
# 59.0 107.0

# %%
r_outliers = []

for i in sorted_rscore:
    if i < lwr_bound or i > upr_bound:
        r_outliers.append(i)

# %%
print(r_outliers)
# Out:
# [25, 25, 25, 25, 30, 30, 30, 30, 30]

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize = (18,10))

# %%
import pandas as pd

# %%
df=pd.read_csv("Book2.csv")

# %%
ax.scatter(df['placement score'], df['placement offer'])

# %%
plt.show()
