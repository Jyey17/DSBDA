# %%
import pandas as pd

# %%
df=pd.read_csv("Book2.csv")

# %%
isnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 isnull()
#
# NameError: name 'isnull' is not defined

# %%
df
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0          72             93             74      2023               92
# 1          64             81             60      2020               82
# 2          80             75             80      2024               86
# 3          73             84             64      2020               92
# 4          63             85             66      2021               90
# ..        ...            ...            ...       ...              ...
# 95         60             80             60      2022               87
# 96         66             92             63      2021               94
# 97         78             77             74      2024               84
# 98         64             88             79      2024               81
# 99         70             89             72      2021               99
#
#     placement offer
# 0                 2
# 1                 3
# 2                 2
# 3                 2
# ...

# %%
df.isnull()
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0       False          False          False     False            False
# 1       False          False          False     False            False
# 2       False          False          False     False            False
# 3       False          False          False     False            False
# 4       False          False          False     False            False
# ..        ...            ...            ...       ...              ...
# 95      False          False          False     False            False
# 96      False          False          False     False            False
# 97      False          False          False     False            False
# 98      False          False          False     False            False
# 99      False          False          False     False            False
#
#     placement offer
# 0             False
# 1             False
# 2             False
# 3             False
# ...

# %%
series = pd.isnull(df["mathscore"])

# %%
df [series]
# Out:
# Empty DataFrame
# Columns: [mathscore, reading score, writing score, clubjoin, placement score, placement offer]
# Index: []

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df['mathscore'] = le.fit_transform(df['mathscore'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df['mathscore'] = le.fit_transform(df['mathscore'])
#
# NameError: name 'le' is not defined

# %%
le = LabelEncoder()

# %%
df['mathscore'] = le.fit_transform(df['mathscore'])

# %%
newdf=df

# %%
df
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0          12             93             74      2023               92
# 1           4             81             60      2020               82
# 2          19             75             80      2024               86
# 3          13             84             64      2020               92
# 4           3             85             66      2021               90
# ..        ...            ...            ...       ...              ...
# 95          0             80             60      2022               87
# 96          6             92             63      2021               94
# 97         17             77             74      2024               84
# 98          4             88             79      2024               81
# 99         10             89             72      2021               99
#
#     placement offer
# 0                 2
# 1                 3
# 2                 2
# 3                 2
# ...

# %%
isnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 isnull()
#
# NameError: name 'isnull' is not defined

# %%
df.isnull()
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0       False          False          False     False            False
# 1       False          False          False     False            False
# 2       False          False          False     False            False
# 3       False          False          False     False            False
# 4       False          False          False     False            False
# ..        ...            ...            ...       ...              ...
# 95      False          False          False     False            False
# 96      False          False          False     False            False
# 97      False          False          False     False            False
# 98      False          False          False     False            False
# 99      False          False          False     False            False
#
#     placement offer
# 0             False
# 1             False
# 2             False
# 3             False
# ...

# %%
df.notnull()
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0        True           True           True      True             True
# 1        True           True           True      True             True
# 2        True           True           True      True             True
# 3        True           True           True      True             True
# 4        True           True           True      True             True
# ..        ...            ...            ...       ...              ...
# 95       True           True           True      True             True
# 96       True           True           True      True             True
# 97       True           True           True      True             True
# 98       True           True           True      True             True
# 99       True           True           True      True             True
#
#     placement offer
# 0              True
# 1              True
# 2              True
# 3              True
# ...

# %%
ndf=df

# %%
df.isnull()
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0       False          False          False     False            False
# 1       False          False          False     False            False
# 2       False          False          False     False            False
# 3       False          False          False     False            False
# 4       False          False          False     False            False
# ..        ...            ...            ...       ...              ...
# 95      False          False          False     False            False
# 96      False          False          False     False            False
# 97      False          False          False     False            False
# 98      False          False          False     False            False
# 99      False          False          False     False            False
#
#     placement offer
# 0             False
# 1             False
# 2             False
# 3             False
# ...

# %%
df=pd.read_csv("Book2.csv")

# %%
df.isnull()
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0       False           True          False     False            False
# 1       False           True          False     False            False
# 2       False           True          False     False            False
# 3       False           True          False     False            False
# 4       False          False          False     False            False
# ..        ...            ...            ...       ...              ...
# 95      False          False          False     False            False
# 96      False           True          False     False            False
# 97      False           True          False     False            False
# 98      False           True          False     False            False
# 99      False          False          False     False            False
#
#     placement offer
# 0             False
# 1             False
# 2             False
# 3             False
# ...

# %%
df
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0        72.0            NaN           74.0    2023.0               92
# 1        64.0            NaN           60.0    2020.0               82
# 2        80.0            NaN           80.0    2024.0               86
# 3        73.0            NaN           64.0    2020.0               92
# 4        63.0           93.0           66.0    2021.0               90
# ..        ...            ...            ...       ...              ...
# 95       60.0           80.0           60.0    2020.0               87
# 96       66.0            NaN           63.0    2020.0               94
# 97       78.0            NaN           74.0    2020.0               84
# 98       64.0            NaN           79.0    2020.0               81
# 99       70.0           89.0           72.0    2020.0               99
#
#     placement offer
# 0                 2
# 1                 3
# 2                 2
# 3                 2
# ...

# %%
ndf=df

# %%
ndf.fillna(0)
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0        72.0            0.0           74.0    2023.0               92
# 1        64.0            0.0           60.0    2020.0               82
# 2        80.0            0.0           80.0    2024.0               86
# 3        73.0            0.0           64.0    2020.0               92
# 4        63.0           93.0           66.0    2021.0               90
# ..        ...            ...            ...       ...              ...
# 95       60.0           80.0           60.0    2020.0               87
# 96       66.0            0.0           63.0    2020.0               94
# 97       78.0            0.0           74.0    2020.0               84
# 98       64.0            0.0           79.0    2020.0               81
# 99       70.0           89.0           72.0    2020.0               99
#
#     placement offer
# 0                 2
# 1                 3
# 2                 2
# 3                 2
# ...

# %%
m_v=df['mathscore'].mean()

# %%
df['mathscore'].fillna(value=m_v,inplace=True)
# Out:
# C:\Users\goura\AppData\Local\Temp\ipykernel_6540\765218506.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['mathscore'].fillna(value=m_v,inplace=True)

# %%
df
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0        72.0            NaN           74.0    2023.0               92
# 1        64.0            NaN           60.0    2020.0               82
# 2        80.0            NaN           80.0    2024.0               86
# 3        73.0            NaN           64.0    2020.0               92
# 4        63.0           93.0           66.0    2021.0               90
# ..        ...            ...            ...       ...              ...
# 95       60.0           80.0           60.0    2020.0               87
# 96       66.0            NaN           63.0    2020.0               94
# 97       78.0            NaN           74.0    2020.0               84
# 98       64.0            NaN           79.0    2020.0               81
# 99       70.0           89.0           72.0    2020.0               99
#
#     placement offer
# 0                 2
# 1                 3
# 2                 2
# 3                 2
# ...

# %%
m_v=df['mathscore'].mean()

# %%
df['mathscore'].fillna(value=m_v,inplace=True)
# Out:
# C:\Users\goura\AppData\Local\Temp\ipykernel_6540\765218506.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['mathscore'].fillna(value=m_v,inplace=True)

# %%
df['mathscore'] = df['mathscore'].fillna(m_v)

# %%
df
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0        72.0            NaN           74.0    2023.0               92
# 1        64.0            NaN           60.0    2020.0               82
# 2        80.0            NaN           80.0    2024.0               86
# 3        73.0            NaN           64.0    2020.0               92
# 4        63.0           93.0           66.0    2021.0               90
# ..        ...            ...            ...       ...              ...
# 95       60.0           80.0           60.0    2020.0               87
# 96       66.0            NaN           63.0    2020.0               94
# 97       78.0            NaN           74.0    2020.0               84
# 98       64.0            NaN           79.0    2020.0               81
# 99       70.0           89.0           72.0    2020.0               99
#
#     placement offer
# 0                 2
# 1                 3
# 2                 2
# 3                 2
# ...

# %%
ndf.replace(to_replace = np.NaN, value = -99)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 ndf.replace(to_replace = np.NaN, value = -99)
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
ndf.replace(to_replace = np.NaN, value = -99)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 ndf.replace(to_replace = np.NaN, value = -99)
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:400, in __getattr__(attr)
#     397     raise AttributeError(__former_attrs__[attr], name=None)
#     399 if attr in __expired_attributes__:
# --> 400     raise AttributeError(
#     401         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     402         f"{__expired_attributes__[attr]}",
#     403         name=None
#     404     )
#     406 if attr == "chararray":
#     407     warnings.warn(
#     408         "`np.chararray` is deprecated and will be removed from "
#     409         "the main namespace in the future. Use an array with a string "
#     410         "or bytes dtype instead.", DeprecationWarning, stacklevel=2)
#
# ...

# %%
ndf.replace(to_replace = np.nan, value = -99)
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0        72.0          -99.0           74.0    2023.0               92
# 1        64.0          -99.0           60.0    2020.0               82
# 2        80.0          -99.0           80.0    2024.0               86
# 3        73.0          -99.0           64.0    2020.0               92
# 4        63.0           93.0           66.0    2021.0               90
# ..        ...            ...            ...       ...              ...
# 95       60.0           80.0           60.0    2020.0               87
# 96       66.0          -99.0           63.0    2020.0               94
# 97       78.0          -99.0           74.0    2020.0               84
# 98       64.0          -99.0           79.0    2020.0               81
# 99       70.0           89.0           72.0    2020.0               99
#
#     placement offer
# 0                 2
# 1                 3
# 2                 2
# 3                 2
# ...

# %%
df=pd.read_csv("Book2.csv")

# %%
df
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0        72.0            NaN           74.0    2023.0               92
# 1        64.0            NaN           60.0    2020.0               82
# 2        80.0            NaN           80.0    2024.0               86
# 3        73.0            NaN           64.0    2020.0               92
# 4        63.0           93.0           66.0    2021.0               90
# ..        ...            ...            ...       ...              ...
# 95       60.0           80.0           60.0    2020.0               87
# 96       66.0            NaN           63.0    2020.0               94
# 97       78.0            NaN           74.0    2020.0               84
# 98       64.0            NaN           79.0    2020.0               81
# 99       70.0           89.0           72.0    2020.0               99
#
#     placement offer
# 0                 2
# 1                 3
# 2                 2
# 3                 2
# ...

# %%
ndf.dropna()
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 4        63.0           93.0           66.0    2021.0               90
# 5        80.0           75.0           65.0    2023.0               98
# 6        62.0           92.0           70.0    2022.0               79
# 7        71.0           79.0           63.0    2023.0               92
# 8        65.0           91.0           69.0    2022.0               97
# ..        ...            ...            ...       ...              ...
# 92       70.0           81.0           62.0    2020.0               80
# 93       65.0           79.0           78.0    2020.0               95
# 94       80.0           84.0           78.0    2020.0               76
# 95       60.0           80.0           60.0    2020.0               87
# 99       70.0           89.0           72.0    2020.0               99
#
#     placement offer
# 4                 2
# 5                 2
# 6                 3
# 7                 2
# ...

# %%
df=pd.read_csv("Book2.csv")

# %%
df
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0        72.0            NaN           74.0    2023.0               92
# 1        64.0            NaN           60.0    2020.0               82
# 2        80.0            NaN           80.0       NaN               86
# 3        73.0            NaN           64.0       NaN               92
# 4        63.0           93.0           66.0       NaN               90
# ..        ...            ...            ...       ...              ...
# 95       60.0           80.0           60.0    2020.0               87
# 96       66.0            NaN           63.0    2020.0               94
# 97       78.0            NaN           74.0    2020.0               84
# 98       64.0            NaN           79.0    2020.0               81
# 99       70.0           89.0           72.0    2020.0               99
#
#     placement offer
# 0                 2
# 1                 3
# 2                 2
# 3                 2
# ...

# %%
ndf.dropna()
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 4        63.0           93.0           66.0    2021.0               90
# 5        80.0           75.0           65.0    2023.0               98
# 6        62.0           92.0           70.0    2022.0               79
# 7        71.0           79.0           63.0    2023.0               92
# 8        65.0           91.0           69.0    2022.0               97
# ..        ...            ...            ...       ...              ...
# 92       70.0           81.0           62.0    2020.0               80
# 93       65.0           79.0           78.0    2020.0               95
# 94       80.0           84.0           78.0    2020.0               76
# 95       60.0           80.0           60.0    2020.0               87
# 99       70.0           89.0           72.0    2020.0               99
#
#     placement offer
# 4                 2
# 5                 2
# 6                 3
# 7                 2
# ...

# %%
ndf.dropna(how = 'all')
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 0        72.0            NaN           74.0    2023.0               92
# 1        64.0            NaN           60.0    2020.0               82
# 2        80.0            NaN           80.0    2024.0               86
# 3        73.0            NaN           64.0    2020.0               92
# 4        63.0           93.0           66.0    2021.0               90
# ..        ...            ...            ...       ...              ...
# 95       60.0           80.0           60.0    2020.0               87
# 96       66.0            NaN           63.0    2020.0               94
# 97       78.0            NaN           74.0    2020.0               84
# 98       64.0            NaN           79.0    2020.0               81
# 99       70.0           89.0           72.0    2020.0               99
#
#     placement offer
# 0                 2
# 1                 3
# 2                 2
# 3                 2
# ...

# %%
ndf.dropna(axis = 1)
# Out:
#     mathscore  placement score  placement offer
# 0        72.0               92                2
# 1        64.0               82                3
# 2        80.0               86                2
# 3        73.0               92                2
# 4        63.0               90                2
# ..        ...              ...              ...
# 95       60.0               87                2
# 96       66.0               94                2
# 97       78.0               84                3
# 98       64.0               81                3
# 99       70.0               99                2
#
# [100 rows x 3 columns]

# %%
new_data = ndf.dropna(axis = 0, how ='any')

# %%
new_data
# Out:
#     mathscore  reading score  writing score  clubjoin  placement score  \
# 4        63.0           93.0           66.0    2021.0               90
# 5        80.0           75.0           65.0    2023.0               98
# 6        62.0           92.0           70.0    2022.0               79
# 7        71.0           79.0           63.0    2023.0               92
# 8        65.0           91.0           69.0    2022.0               97
# ..        ...            ...            ...       ...              ...
# 92       70.0           81.0           62.0    2020.0               80
# 93       65.0           79.0           78.0    2020.0               95
# 94       80.0           84.0           78.0    2020.0               76
# 95       60.0           80.0           60.0    2020.0               87
# 99       70.0           89.0           72.0    2020.0               99
#
#     placement offer
# 4                 2
# 5                 2
# 6                 3
# 7                 2
# ...
